# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/dhrebeniuk/dlschool_super_resolution
# Out:
# Cloning into 'dlschool_super_resolution'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 37 (delta 10), reused 30 (delta 5), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
# %cd dlschool_super_resolution
# Out:
# /content/dlschool_super_resolution

# %% [markdown]
# Download dataset

# %%
# !sh bin/download_dataset.sh

# %% [markdown]
# Start train

# %%
# !python ./train.py
# Out:
# Epoch: 0 	Training Generator Loss: 6164.374479  	Validation Generator Loss: 9158.279688 	Training Discriminator Loss:0.642627 	Validation Discriminator Loss: 0.402140
