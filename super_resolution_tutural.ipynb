# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/dhrebeniuk/dlschool_super_resolution
# Out:
# Cloning into 'dlschool_super_resolution'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 20 (delta 2), reused 20 (delta 2), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
# %cd dlschool_super_resolution
# Out:
# /content/dlschool_super_resolution

# %% [markdown]
# Download dataset

# %%
# !sh bin/download_dataset.sh
# Out:
# --2021-02-05 22:31:40--  https://uofi.box.com/shared/static/65upg43jjd0a4cwsiqgl6o6ixube6klm.zip
# Resolving uofi.box.com (uofi.box.com)... 103.116.4.197
# Connecting to uofi.box.com (uofi.box.com)|103.116.4.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/65upg43jjd0a4cwsiqgl6o6ixube6klm.zip [following]
# --2021-02-05 22:31:40--  https://uofi.box.com/public/static/65upg43jjd0a4cwsiqgl6o6ixube6klm.zip
# Reusing existing connection to uofi.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://uofi.app.box.com/public/static/65upg43jjd0a4cwsiqgl6o6ixube6klm.zip [following]
# --2021-02-05 22:31:40--  https://uofi.app.box.com/public/static/65upg43jjd0a4cwsiqgl6o6ixube6klm.zip
# Resolving uofi.app.box.com (uofi.app.box.com)... 103.116.4.201
# Connecting to uofi.app.box.com (uofi.app.box.com)|103.116.4.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# Start train

# %%
# !python ./train.py
# Out:
# Epoch: 740 	Training Generator Loss: 5830.430208  	Validation Generator Loss: 7863.505859 	Training Discriminator Loss:0.119197 	Validation Discriminator Loss: 0.229311
# Epoch: 741 	Training Generator Loss: 5829.857813  	Validation Generator Loss: 7863.433984 	Training Discriminator Loss:0.119113 	Validation Discriminator Loss: 0.229686
# Epoch: 742 	Training Generator Loss: 5829.286979  	Validation Generator Loss: 7861.831641 	Training Discriminator Loss:0.119030 	Validation Discriminator Loss: 0.229829
# Epoch: 743 	Training Generator Loss: 5828.708854  	Validation Generator Loss: 7861.744531 	Training Discriminator Loss:0.118946 	Validation Discriminator Loss: 0.229708
# Epoch: 744 	Training Generator Loss: 5828.125000  	Validation Generator Loss: 7860.741406 	Training Discriminator Loss:0.118862 	Validation Discriminator Loss: 0.229491
# ...
